# %% [markdown]
# <a href="https://colab.research.google.com/github/heispv/tf-class-december2023/blob/master/03_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Biam va yek seri X tarif konim
X = np.linspace(-30, 50, 60) #Start, Stop, # of numbers
X
# Out:
# array([-30.        , -28.6440678 , -27.28813559, -25.93220339,
#        -24.57627119, -23.22033898, -21.86440678, -20.50847458,
#        -19.15254237, -17.79661017, -16.44067797, -15.08474576,
#        -13.72881356, -12.37288136, -11.01694915,  -9.66101695,
#         -8.30508475,  -6.94915254,  -5.59322034,  -4.23728814,
#         -2.88135593,  -1.52542373,  -0.16949153,   1.18644068,
#          2.54237288,   3.89830508,   5.25423729,   6.61016949,
#          7.96610169,   9.3220339 ,  10.6779661 ,  12.03389831,
#         13.38983051,  14.74576271,  16.10169492,  17.45762712,
#         18.81355932,  20.16949153,  21.52542373,  22.88135593,
#         24.23728814,  25.59322034,  26.94915254,  28.30508475,
#         29.66101695,  31.01694915,  32.37288136,  33.72881356,
#         35.08474576,  36.44067797,  37.79661017,  39.15254237,
#         40.50847458,  41.86440678,  43.22033898,  44.57627119,
#         45.93220339,  47.28813559,  48.6440678 ,  50.        ])

# %%
# Baraye tarif kardane y
shib = 2
arz_az_mabda = 1.5

y = (X * shib) + arz_az_mabda

# %%
y
# Out:
# array([-58.5       , -55.78813559, -53.07627119, -50.36440678,
#        -47.65254237, -44.94067797, -42.22881356, -39.51694915,
#        -36.80508475, -34.09322034, -31.38135593, -28.66949153,
#        -25.95762712, -23.24576271, -20.53389831, -17.8220339 ,
#        -15.11016949, -12.39830508,  -9.68644068,  -6.97457627,
#         -4.26271186,  -1.55084746,   1.16101695,   3.87288136,
#          6.58474576,   9.29661017,  12.00847458,  14.72033898,
#         17.43220339,  20.1440678 ,  22.8559322 ,  25.56779661,
#         28.27966102,  30.99152542,  33.70338983,  36.41525424,
#         39.12711864,  41.83898305,  44.55084746,  47.26271186,
#         49.97457627,  52.68644068,  55.39830508,  58.11016949,
#         60.8220339 ,  63.53389831,  66.24576271,  68.95762712,
#         71.66949153,  74.38135593,  77.09322034,  79.80508475,
#         82.51694915,  85.22881356,  87.94067797,  90.65254237,
#         93.36440678,  96.07627119,  98.78813559, 101.5       ])

# %%
# biaim va nemoodar ro bebinim che shekli mishe
plt.scatter(X, y)
plt.show()

# %%
# Biam va noise ezafe konim be datamoon
shib = 2
arz_az_mabda = 1.5
noise = 0.2

y = (X * shib) + arz_az_mabda + (np.random.randn(len(X)) * noise * np.abs(X))

# %%
plt.scatter(X, y)
plt.show()

# %%
# Biam va noise ezafe konim be datamoon ama bar asase index e X
shib = 2
arz_az_mabda = 1.5
noise = 0.2
index = np.arange(len(X))

y = (X * shib) + arz_az_mabda + (np.random.randn(len(X)) * noise * index)

# %%
plt.scatter(X, y)
plt.show()

# %% [markdown]
# # Sakhtane Model be komake TF
#
# 1. Model ro be komake `Sequential API` e TF misazim.
# 2. Model ro `compile` mikonim.
# * yani `optimizer` va `loss function` va `metrics` ro barash tain mikonam.
# 3. Model ro `train` mikonim.

# %%
X.shape
# Out:
# (60,)

# %% [markdown]
# ## First model

# %%
# 1. Sakhtane model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=(1,))
])

# %%
# 2. Compile the model
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001),
    loss=tf.keras.losses.mse,
    metrics=['accuracy']
)

# %%
# 3. Fit the model
history = model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 0s 9ms/step - loss: 2978.7805 - accuracy: 0.0000e+00
# Epoch 2/20
# 2/2 [==============================] - 0s 10ms/step - loss: 1673.8434 - accuracy: 0.0000e+00
# Epoch 3/20
# 2/2 [==============================] - 0s 9ms/step - loss: 973.1042 - accuracy: 0.0000e+00
# Epoch 4/20
# 2/2 [==============================] - 0s 8ms/step - loss: 576.6910 - accuracy: 0.0000e+00
# Epoch 5/20
# 2/2 [==============================] - 0s 8ms/step - loss: 348.6401 - accuracy: 0.0000e+00
# Epoch 6/20
# 2/2 [==============================] - 0s 8ms/step - loss: 217.4839 - accuracy: 0.0000e+00
# Epoch 7/20
# 2/2 [==============================] - 0s 8ms/step - loss: 142.1999 - accuracy: 0.0000e+00
# Epoch 8/20
# 2/2 [==============================] - 0s 11ms/step - loss: 99.8577 - accuracy: 0.0000e+00
# Epoch 9/20
# 2/2 [==============================] - 0s 8ms/step - loss: 75.0283 - accuracy: 0.0000e+00
# Epoch 10/20
# 2/2 [==============================] - 0s 8ms/step - loss: 60.6015 - accuracy: 0.0000e+00
# Epoch 11/20
# 2/2 [==============================] - 0s 8ms/step - loss: 52.4782 - accuracy: 0.0000e+00
# Epoch 12/20
# 2/2 [==============================] - 0s 7ms/step - loss: 47.9701 - accuracy: 0.0000e+00
# Epoch 13/20
# 2/2 [==============================] - 0s 13ms/step - loss: 45.4135 - accuracy: 0.0000e+00
# Epoch 14/20
# 2/2 [==============================] - 0s 12ms/step - loss: 44.3699 - accuracy: 0.0000e+00
# Epoch 15/20
# 2/2 [==============================] - 0s 9ms/step - loss: 43.2376 - accuracy: 0.0000e+00
# Epoch 16/20
# 2/2 [==============================] - 0s 9ms/step - loss: 42.7896 - accuracy: 0.0000e+00
# Epoch 17/20
# 2/2 [==============================] - 0s 7ms/step - loss: 42.3639 - accuracy: 0.0000e+00
# Epoch 18/20
# 2/2 [==============================] - 0s 8ms/step - loss: 42.1874 - accuracy: 0.0000e+00
# Epoch 19/20
# 2/2 [==============================] - 0s 8ms/step - loss: 42.2108 - accuracy: 0.0000e+00
# Epoch 20/20
# 2/2 [==============================] - 0s 9ms/step - loss: 42.0073 - accuracy: 0.0000e+00

# %%
plt.plot(history.history["loss"])
plt.title("Model's Performance")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

# %% [markdown]
# ## Second model
# Inja mikhaim ghabl az sakhte model data moon ro normalize konim

# %%
X
# Out:
# array([-30.        , -28.6440678 , -27.28813559, -25.93220339,
#        -24.57627119, -23.22033898, -21.86440678, -20.50847458,
#        -19.15254237, -17.79661017, -16.44067797, -15.08474576,
#        -13.72881356, -12.37288136, -11.01694915,  -9.66101695,
#         -8.30508475,  -6.94915254,  -5.59322034,  -4.23728814,
#         -2.88135593,  -1.52542373,  -0.16949153,   1.18644068,
#          2.54237288,   3.89830508,   5.25423729,   6.61016949,
#          7.96610169,   9.3220339 ,  10.6779661 ,  12.03389831,
#         13.38983051,  14.74576271,  16.10169492,  17.45762712,
#         18.81355932,  20.16949153,  21.52542373,  22.88135593,
#         24.23728814,  25.59322034,  26.94915254,  28.30508475,
#         29.66101695,  31.01694915,  32.37288136,  33.72881356,
#         35.08474576,  36.44067797,  37.79661017,  39.15254237,
#         40.50847458,  41.86440678,  43.22033898,  44.57627119,
#         45.93220339,  47.28813559,  48.6440678 ,  50.        ])

# %% [markdown]
# Be komake `X.mean()` miangin data haro migirim va be komake `X.std()` standard deviation oon ro hesab mikonim chonke baraye normalize kardane data bayad har data ro menhaye miangin konim va bar standard deviation oon taghsim konim

# %%
X_normalized = (X - X.mean()) / X.std()
y_normalized = (y - y.mean()) / y.std()

# %% [markdown]
# * agar check konim mibinim ke X_normalized miangin esh 0 hast va standard deviation oon barabar ba 1 hastesh ke in model parakandegi data baraye Neural Network kheyli khoobe va yadgiri ro behtar mikone.

# %%
X_normalized
# Out:
# array([-1.7034199 , -1.64567685, -1.5879338 , -1.53019075, -1.47244771,
#        -1.41470466, -1.35696161, -1.29921857, -1.24147552, -1.18373247,
#        -1.12598942, -1.06824638, -1.01050333, -0.95276028, -0.89501723,
#        -0.83727419, -0.77953114, -0.72178809, -0.66404504, -0.606302  ,
#        -0.54855895, -0.4908159 , -0.43307286, -0.37532981, -0.31758676,
#        -0.25984371, -0.20210067, -0.14435762, -0.08661457, -0.02887152,
#         0.02887152,  0.08661457,  0.14435762,  0.20210067,  0.25984371,
#         0.31758676,  0.37532981,  0.43307286,  0.4908159 ,  0.54855895,
#         0.606302  ,  0.66404504,  0.72178809,  0.77953114,  0.83727419,
#         0.89501723,  0.95276028,  1.01050333,  1.06824638,  1.12598942,
#         1.18373247,  1.24147552,  1.29921857,  1.35696161,  1.41470466,
#         1.47244771,  1.53019075,  1.5879338 ,  1.64567685,  1.7034199 ])

# %%
X_normalized.std()
# Out:
# 0.9999999999999999

# %%
# 1. Sakhtane model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=(1,))
])

# %%
# 2. Compile the model
model_2.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss=tf.keras.losses.mse,
    metrics=['accuracy']
)

# %%
# 3. Fit the model
history = model_2.fit(X_normalized, y_normalized, epochs=50)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5819 - accuracy: 0.0000e+00
# Epoch 2/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5385 - accuracy: 0.0000e+00
# Epoch 3/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4981 - accuracy: 0.0000e+00
# Epoch 4/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4610 - accuracy: 0.0000e+00
# Epoch 5/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4264 - accuracy: 0.0000e+00
# Epoch 6/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3948 - accuracy: 0.0000e+00
# Epoch 7/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3656 - accuracy: 0.0000e+00
# Epoch 8/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3388 - accuracy: 0.0000e+00
# Epoch 9/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3137 - accuracy: 0.0000e+00
# Epoch 10/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2901 - accuracy: 0.0000e+00
# Epoch 11/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2688 - accuracy: 0.0000e+00
# Epoch 12/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2497 - accuracy: 0.0000e+00
# Epoch 13/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2312 - accuracy: 0.0000e+00
# Epoch 14/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2146 - accuracy: 0.0000e+00
# Epoch 15/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1993 - accuracy: 0.0000e+00
# Epoch 16/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1853 - accuracy: 0.0000e+00
# Epoch 17/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1724 - accuracy: 0.0000e+00
# Epoch 18/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1604 - accuracy: 0.0000e+00
# Epoch 19/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1494 - accuracy: 0.0000e+00
# Epoch 20/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1393 - accuracy: 0.0000e+00
# Epoch 21/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1300 - accuracy: 0.0000e+00
# Epoch 22/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1213 - accuracy: 0.0000e+00
# Epoch 23/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1133 - accuracy: 0.0000e+00
# Epoch 24/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1060 - accuracy: 0.0000e+00
# Epoch 25/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0991 - accuracy: 0.0000e+00
# Epoch 26/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0928 - accuracy: 0.0000e+00
# Epoch 27/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0870 - accuracy: 0.0000e+00
# Epoch 28/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0817 - accuracy: 0.0000e+00
# Epoch 29/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0767 - accuracy: 0.0000e+00
# Epoch 30/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0721 - accuracy: 0.0000e+00
# Epoch 31/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0679 - accuracy: 0.0000e+00
# Epoch 32/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0640 - accuracy: 0.0000e+00
# Epoch 33/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0605 - accuracy: 0.0000e+00
# Epoch 34/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0572 - accuracy: 0.0000e+00
# Epoch 35/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0541 - accuracy: 0.0000e+00
# Epoch 36/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0513 - accuracy: 0.0000e+00
# Epoch 37/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0487 - accuracy: 0.0000e+00
# Epoch 38/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0463 - accuracy: 0.0000e+00
# Epoch 39/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0442 - accuracy: 0.0000e+00
# Epoch 40/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0421 - accuracy: 0.0000e+00
# Epoch 41/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0403 - accuracy: 0.0000e+00
# Epoch 42/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0385 - accuracy: 0.0000e+00
# Epoch 43/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0370 - accuracy: 0.0000e+00
# Epoch 44/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0355 - accuracy: 0.0000e+00
# Epoch 45/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0341 - accuracy: 0.0000e+00
# Epoch 46/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0328 - accuracy: 0.0000e+00
# Epoch 47/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0317 - accuracy: 0.0000e+00
# Epoch 48/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0306 - accuracy: 0.0000e+00
# Epoch 49/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0296 - accuracy: 0.0000e+00
# Epoch 50/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0287 - accuracy: 0.0000e+00

# %%
plt.plot(history.history["loss"])
plt.title("Model's Performance")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

# %% [markdown]
# ## How to split the data to training set and validation set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_normalized,
                                                    y_normalized,
                                                    test_size=0.2)

# %%
X_train.shape, X_test.shape
# Out:
# ((48,), (12,))

# %% [markdown]
# # Exercise
# 1. Yek data amade konin ke yek moadele daraje 2 hast. noise ro ham behesh ezafe konin.
# 2. yek neural network besazin ke input_shape=(1,) hast, bad Dense layer ba 4 neuron dare, bad yek Dense layer ba 1 neuron dare.
# 3. Va model ro train konin va nemoodaresh ro rasm konin.
#
# * normalize kardane data faramoosh nashe.
